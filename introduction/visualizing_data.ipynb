# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
import os

BASE_DIR = "/Users/user/Desktop/Projects/data-science/data-ds"
FILE_PATH = ""
CUSTOM_PATH = os.path.join(BASE_DIR, FILE_PATH)

df = pd.read_csv(CUSTOM_PATH)

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline 

age_list = np.arange(10, 80, 5)
weight_list = np.random.randint(20, 90, 14)

plt.plot(age_list, weight_list, "y")
plt.xlabel("Age")
plt.ylabel("Weight")
plt.title("Age vs Weight")
plt.show()

# %%
# Showing different plots side by side
plt.subplot(1,2,1)
plt.plot(age_list, weight_list, "y")
plt.subplot(1,2,2)
plt.plot(age_list, weight_list, "g")
plt.show()
